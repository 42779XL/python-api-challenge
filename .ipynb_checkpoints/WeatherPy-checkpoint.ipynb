# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# My Analysis By Plots Observation
#
# Temperature trends
# From the City Latitude vs. Max Temperature plot, we saw an obvious temperature changes along the equator.
# Cities are closer to the equator the temperature becomes higher and higher. Cities are south of the equator have much higher
# temperature than cities are north of the equator. This may be due to the way of earth tilting, so that south side of equator
# still closer to the sun.
#
# Humidity and Wind trends
# From plots City Latitude vs. Wind Speed and City Latitude vs. Humidity at this time of the year, there are not obvious
# different between north and south hemisphere. However, more further north or further south of equator, more wind and humidity.
#
# Cloudiness trends
# From plot City Latitude vs. Cloudiness, we observed that there is no significant difference cloudiness between south and north
# hemisphere. However, by observation there are high percentage cloudiness dities density roughly in range 85 to 100% and very
# low percentage cloudiness cities density less than 3%, but low cities density cloudiness in range 4% to 84% globally.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from datetime import date

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 583

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save api_keys information and build query URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# get first city response information for further analysis reference
response = requests.get(query_url + city).json()
response
# Out:
# {'coord': {'lon': -88.55, 'lat': 13.27},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 82.4,
#   'pressure': 1009,
#   'humidity': 74,
#   'temp_min': 82.4,
#   'temp_max': 82.4},
#  'visibility': 10000,
#  'wind': {'speed': 3.36, 'deg': 290},
#  'clouds': {'all': 40},
#  'dt': 1573950732,
#  'sys': {'type': 1,
#   'id': 7222,
#   'country': 'SV',
#   'sunrise': 1573905228,
#   'sunset': 1573946661},
#  'timezone': -21600,
#  'id': 3584003,
#  'name': 'Puerto El Triunfo',
#  'cod': 200}

# %%
# initiate city number
city_number = 1
set_number = 1

# set up lists to hold reponse data
city_name = []
country = []
lat = []
long = []
date = []
clouds = []
humidity = []
maxTemp = []
temp = []
wind = []

# print data report header
print(''*50)
print('Beginning Data Retrieval')
print("-"*50)

# Loop through the list of cities and perform a request for data on each
for city in cities:
    if city_number <= 50:
    
    # Try to access data that doesn't exist and continuing complete the report
        try:
            response = requests.get(query_url + city).json()
            city_name.append(response['name'])
            country.append(response['sys']['country'])
            lat.append(response['coord']['lat'])
            long.append(response['coord']['lon'])
            date.append(response['dt'])
            clouds.append(response['clouds']['all'])
            humidity.append(response['main']['humidity'])
            maxTemp.append(response['main']['temp_max'])
            temp.append(response['main']['temp'])
            wind.append(response['wind']['speed'])
                        
            # start printing report
            print(f'Processing Record {city_number} of set{set_number} | {city}')
            city_number = city_number + 1
        except KeyError:
            print(f'City not found. Skipping ...')
    else:
        city_number = 1
        # start another set of cities search
        set_number = set_number + 1

# print data report footer
print("-"*50)
print('Data Retrieval Complete')      
print('-'*50)
# Out:
# Beginning Data Retrieval
# --------------------------------------------------
# Processing Record 1 of set1 | ponta do sol
# Processing Record 2 of set1 | rikitea
# Processing Record 3 of set1 | mahebourg
# Processing Record 4 of set1 | atuona
# Processing Record 5 of set1 | devils lake
# Processing Record 6 of set1 | prejmer
# Processing Record 7 of set1 | katherine
# City not found. Skipping ...
# Processing Record 8 of set1 | mataura
# Processing Record 9 of set1 | isangel
# Processing Record 10 of set1 | los llanos de aridane
# Processing Record 11 of set1 | saskylakh
# Processing Record 12 of set1 | chuy
# Processing Record 13 of set1 | kundiawa
# Processing Record 14 of set1 | sao filipe
# Processing Record 15 of set1 | mountain home
# Processing Record 16 of set1 | souillac
# Processing Record 17 of set1 | esperance
# Processing Record 18 of set1 | tasiilaq
# Processing Record 19 of set1 | aquiraz
# Processing Record 20 of set1 | gualaquiza
# Processing Record 21 of set1 | bredasdorp
# Processing Record 22 of set1 | vozhega
# Processing Record 23 of set1 | sao joao da barra
# Processing Record 24 of set1 | butaritari
# Processing Record 25 of set1 | namibe
# Processing Record 26 of set1 | ushuaia
# Processing Record 27 of set1 | tura
# Processing Record 28 of set1 | viedma
# City not found. Skipping ...
# Processing Record 29 of set1 | albany
# City not found. Skipping ...
# Processing Record 30 of set1 | nikolskoye
# Processing Record 31 of set1 | ostrovnoy
# Processing Record 32 of set1 | leshukonskoye
# Processing Record 33 of set1 | jamestown
# Processing Record 34 of set1 | touros
# Processing Record 35 of set1 | arraial do cabo
# Processing Record 36 of set1 | saint-philippe
# Processing Record 37 of set1 | thompson
# Processing Record 38 of set1 | kodiak
# Processing Record 39 of set1 | great yarmouth
# Processing Record 40 of set1 | necochea
# Processing Record 41 of set1 | kaitangata
# Processing Record 42 of set1 | valparaiso
# Processing Record 43 of set1 | lashio
# Processing Record 44 of set1 | chokurdakh
# Processing Record 45 of set1 | taltal
# Processing Record 46 of set1 | ahipara
# Processing Record 47 of set1 | port alfred
# Processing Record 48 of set1 | talnakh
# Processing Record 49 of set1 | busselton
# Processing Record 50 of set1 | bodden town
# Processing Record 1 of set2 | flinders
# Processing Record 2 of set2 | tamiahua
# Processing Record 3 of set2 | saint george
# City not found. Skipping ...
# Processing Record 4 of set2 | carbonia
# Processing Record 5 of set2 | mar del plata
# Processing Record 6 of set2 | celestun
# Processing Record 7 of set2 | puerto ayora
# Processing Record 8 of set2 | hasaki
# Processing Record 9 of set2 | castro
# Processing Record 10 of set2 | windsor
# City not found. Skipping ...
# Processing Record 11 of set2 | torbay
# Processing Record 12 of set2 | kota kinabalu
# Processing Record 13 of set2 | victoria
# Processing Record 14 of set2 | tuxtla
# City not found. Skipping ...
# Processing Record 15 of set2 | hilo
# Processing Record 16 of set2 | fenoarivo
# Processing Record 17 of set2 | aswan
# Processing Record 18 of set2 | ojinaga
# Processing Record 19 of set2 | punta arenas
# Processing Record 20 of set2 | avarua
# Processing Record 21 of set2 | kapaa
# City not found. Skipping ...
# City not found. Skipping ...
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 22 of set2 | dikson
# Processing Record 23 of set2 | katsuura
# Processing Record 24 of set2 | vaini
# Processing Record 25 of set2 | chara
# Processing Record 26 of set2 | khatanga
# Processing Record 27 of set2 | ribeira grande
# Processing Record 28 of set2 | westport
# Processing Record 29 of set2 | poum
# Processing Record 30 of set2 | carnarvon
# Processing Record 31 of set2 | pevek
# Processing Record 32 of set2 | angra dos reis
# Processing Record 33 of set2 | tuktoyaktuk
# Processing Record 34 of set2 | georgetown
# Processing Record 35 of set2 | tual
# Processing Record 36 of set2 | kirakira
# Processing Record 37 of set2 | peleduy
# Processing Record 38 of set2 | vitim
# Processing Record 39 of set2 | itarema
# Processing Record 40 of set2 | comodoro rivadavia
# City not found. Skipping ...
# Processing Record 41 of set2 | guerrero negro
# Processing Record 42 of set2 | chala
# City not found. Skipping ...
# Processing Record 43 of set2 | iqaluit
# Processing Record 44 of set2 | cape town
# Processing Record 45 of set2 | meadow lake
# Processing Record 46 of set2 | barrow
# Processing Record 47 of set2 | sitka
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 48 of set2 | chicxulub
# Processing Record 49 of set2 | emerald
# Processing Record 50 of set2 | airai
# Processing Record 1 of set3 | salalah
# Processing Record 2 of set3 | balod
# Processing Record 3 of set3 | new norfolk
# City not found. Skipping ...
# Processing Record 4 of set3 | dalhem
# Processing Record 5 of set3 | nelson bay
# Processing Record 6 of set3 | hermanus
# Processing Record 7 of set3 | snezhnogorsk
# Processing Record 8 of set3 | lata
# Processing Record 9 of set3 | yarada
# Processing Record 10 of set3 | bethel
# Processing Record 11 of set3 | ko samui
# Processing Record 12 of set3 | bluff
# City not found. Skipping ...
# Processing Record 13 of set3 | naze
# Processing Record 14 of set3 | constitucion
# Processing Record 15 of set3 | hobart
# Processing Record 16 of set3 | plettenberg bay
# Processing Record 17 of set3 | gat
# Processing Record 18 of set3 | mizusawa
# Processing Record 19 of set3 | clyde river
# Processing Record 20 of set3 | vilhena
# Processing Record 21 of set3 | koflach
# Processing Record 22 of set3 | san francisco
# Processing Record 23 of set3 | bulgan
# Processing Record 24 of set3 | shenjiamen
# Processing Record 25 of set3 | kamina
# City not found. Skipping ...
# Processing Record 26 of set3 | dauphin
# Processing Record 27 of set3 | porto walter
# Processing Record 28 of set3 | camacha
# Processing Record 29 of set3 | tadpatri
# Processing Record 30 of set3 | labuhan
# Processing Record 31 of set3 | quelimane
# Processing Record 32 of set3 | petropavlovsk-kamchatskiy
# Processing Record 33 of set3 | moose factory
# Processing Record 34 of set3 | aparecida do taboado
# Processing Record 35 of set3 | cherskiy
# Processing Record 36 of set3 | cidreira
# Processing Record 37 of set3 | coquimbo
# Processing Record 38 of set3 | tahoua
# Processing Record 39 of set3 | strezhevoy
# Processing Record 40 of set3 | ancud
# Processing Record 41 of set3 | bilma
# Processing Record 42 of set3 | huarmey
# City not found. Skipping ...
# Processing Record 43 of set3 | spring hill
# Processing Record 44 of set3 | concepcion del oro
# Processing Record 45 of set3 | qaanaaq
# City not found. Skipping ...
# Processing Record 46 of set3 | tarauaca
# Processing Record 47 of set3 | gavrilov posad
# Processing Record 48 of set3 | longyearbyen
# Processing Record 49 of set3 | ayr
# Processing Record 50 of set3 | cascais
# Processing Record 1 of set4 | sorland
# Processing Record 2 of set4 | cockburn town
# Processing Record 3 of set4 | pangnirtung
# Processing Record 4 of set4 | klaksvik
# Processing Record 5 of set4 | presidencia roque saenz pena
# Processing Record 6 of set4 | takaka
# Processing Record 7 of set4 | fortuna
# Processing Record 8 of set4 | east london
# Processing Record 9 of set4 | lyuban
# Processing Record 10 of set4 | norman wells
# Processing Record 11 of set4 | hakodate
# Processing Record 12 of set4 | ati
# Processing Record 13 of set4 | bambous virieux
# Processing Record 14 of set4 | tezu
# Processing Record 15 of set4 | smoky lake
# Processing Record 16 of set4 | zhuhai
# Processing Record 17 of set4 | cassilandia
# Processing Record 18 of set4 | kisesa
# Processing Record 19 of set4 | mount gambier
# Processing Record 20 of set4 | yellowknife
# Processing Record 21 of set4 | noumea
# Processing Record 22 of set4 | ilulissat
# Processing Record 23 of set4 | port hedland
# Processing Record 24 of set4 | karratha
# Processing Record 25 of set4 | altayskoye
# Processing Record 26 of set4 | homer
# Processing Record 27 of set4 | nome
# Processing Record 28 of set4 | dzhebariki-khaya
# Processing Record 29 of set4 | roald
# Processing Record 30 of set4 | kruisfontein
# City not found. Skipping ...
# Processing Record 31 of set4 | churapcha
# Processing Record 32 of set4 | susanville
# Processing Record 33 of set4 | zhoucheng
# Processing Record 34 of set4 | nacala
# Processing Record 35 of set4 | mount isa
# City not found. Skipping ...
# Processing Record 36 of set4 | mana
# Processing Record 37 of set4 | loandjili
# Processing Record 38 of set4 | sambava
# Processing Record 39 of set4 | samfya
# Processing Record 40 of set4 | vertientes
# Processing Record 41 of set4 | sai buri
# Processing Record 42 of set4 | port elizabeth
# Processing Record 43 of set4 | cayenne
# City not found. Skipping ...
# Processing Record 44 of set4 | sinnamary
# Processing Record 45 of set4 | shyryayeve
# Processing Record 46 of set4 | berdigestyakh
# Processing Record 47 of set4 | wamba
# City not found. Skipping ...
# Processing Record 48 of set4 | bangassou
# Processing Record 49 of set4 | dingle
# Processing Record 50 of set4 | teeli
# Processing Record 1 of set5 | eskil
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 2 of set5 | faanui
# City not found. Skipping ...
# Processing Record 3 of set5 | hithadhoo
# Processing Record 4 of set5 | yongzhou
# Processing Record 5 of set5 | barra patuca
# City not found. Skipping ...
# Processing Record 6 of set5 | biak
# Processing Record 7 of set5 | wenling
# Processing Record 8 of set5 | cabo san lucas
# Processing Record 9 of set5 | tiksi
# Processing Record 10 of set5 | upernavik
# Processing Record 11 of set5 | lady lake
# Processing Record 12 of set5 | aklavik
# Processing Record 13 of set5 | antofagasta
# Processing Record 14 of set5 | lompoc
# Processing Record 15 of set5 | suntar
# Processing Record 16 of set5 | seydi
# Processing Record 17 of set5 | rawson
# Processing Record 18 of set5 | shimoda
# Processing Record 19 of set5 | dzerzhinsk
# Processing Record 20 of set5 | roma
# Processing Record 21 of set5 | baruun-urt
# Processing Record 22 of set5 | lumphat
# Processing Record 23 of set5 | saint anthony
# Processing Record 24 of set5 | srednekolymsk
# Processing Record 25 of set5 | lebu
# Processing Record 26 of set5 | san patricio
# Processing Record 27 of set5 | kaduqli
# Processing Record 28 of set5 | vestmannaeyjar
# Processing Record 29 of set5 | broken hill
# Processing Record 30 of set5 | san juan
# Processing Record 31 of set5 | wasco
# City not found. Skipping ...
# Processing Record 32 of set5 | lagoa
# Processing Record 33 of set5 | hirara
# Processing Record 34 of set5 | qaqortoq
# Processing Record 35 of set5 | hami
# Processing Record 36 of set5 | hamburg
# City not found. Skipping ...
# Processing Record 37 of set5 | dakar
# Processing Record 38 of set5 | harper
# Processing Record 39 of set5 | vikindu
# Processing Record 40 of set5 | shepsi
# City not found. Skipping ...
# Processing Record 41 of set5 | hobyo
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 42 of set5 | maumere
# Processing Record 43 of set5 | severo-kurilsk
# Processing Record 44 of set5 | evanston
# Processing Record 45 of set5 | college
# Processing Record 46 of set5 | lima
# Processing Record 47 of set5 | boa vista
# Processing Record 48 of set5 | provideniya
# Processing Record 49 of set5 | general pico
# Processing Record 50 of set5 | waynesville
# City not found. Skipping ...
# Processing Record 1 of set6 | baracoa
# Processing Record 2 of set6 | teguldet
# Processing Record 3 of set6 | batabano
# City not found. Skipping ...
# Processing Record 4 of set6 | bandarbeyla
# Processing Record 5 of set6 | wipperfurth
# Processing Record 6 of set6 | yulara
# Processing Record 7 of set6 | muros
# Processing Record 8 of set6 | te anau
# City not found. Skipping ...
# Processing Record 9 of set6 | saint-pierre
# Processing Record 10 of set6 | scarborough
# Processing Record 11 of set6 | anadyr
# Processing Record 12 of set6 | half moon bay
# Processing Record 13 of set6 | prince rupert
# Processing Record 14 of set6 | komsomolskiy
# Processing Record 15 of set6 | kavieng
# Processing Record 16 of set6 | baherden
# City not found. Skipping ...
# Processing Record 17 of set6 | tortoli
# Processing Record 18 of set6 | lasa
# Processing Record 19 of set6 | margate
# Processing Record 20 of set6 | foumban
# Processing Record 21 of set6 | kokopo
# Processing Record 22 of set6 | pervomayskoye
# Processing Record 23 of set6 | beringovskiy
# Processing Record 24 of set6 | la asuncion
# Processing Record 25 of set6 | byron bay
# Processing Record 26 of set6 | maceio
# Processing Record 27 of set6 | ulaanbaatar
# Processing Record 28 of set6 | acari
# Processing Record 29 of set6 | ossora
# Processing Record 30 of set6 | daru
# City not found. Skipping ...
# Processing Record 31 of set6 | ornskoldsvik
# Processing Record 32 of set6 | mayo
# Processing Record 33 of set6 | lorengau
# Processing Record 34 of set6 | kaeo
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 35 of set6 | rexburg
# Processing Record 36 of set6 | pangody
# City not found. Skipping ...
# Processing Record 37 of set6 | meulaboh
# Processing Record 38 of set6 | geraldton
# Processing Record 39 of set6 | leningradskiy
# Processing Record 40 of set6 | chicama
# Processing Record 41 of set6 | tuatapere
# City not found. Skipping ...
# Processing Record 42 of set6 | zhigansk
# Processing Record 43 of set6 | oksfjord
# Processing Record 44 of set6 | minudasht
# City not found. Skipping ...
# Processing Record 45 of set6 | luderitz
# Processing Record 46 of set6 | lavrentiya
# Processing Record 47 of set6 | koslan
# Processing Record 48 of set6 | oktyabrskiy
# Processing Record 49 of set6 | gwanda
# Processing Record 50 of set6 | tigzirt
# Processing Record 1 of set7 | mukhen
# Processing Record 2 of set7 | fort nelson
# Processing Record 3 of set7 | jalu
# Processing Record 4 of set7 | port lincoln
# Processing Record 5 of set7 | hambantota
# Processing Record 6 of set7 | adrar
# Processing Record 7 of set7 | la paz
# Processing Record 8 of set7 | bonthe
# Processing Record 9 of set7 | jiamusi
# Processing Record 10 of set7 | magaria
# Processing Record 11 of set7 | teguise
# Processing Record 12 of set7 | puerto colombia
# Processing Record 13 of set7 | portage
# Processing Record 14 of set7 | saldanha
# Processing Record 15 of set7 | ust-ilimsk
# Processing Record 16 of set7 | hollins
# Processing Record 17 of set7 | fare
# City not found. Skipping ...
# Processing Record 18 of set7 | narsaq
# Processing Record 19 of set7 | puerto carreno
# Processing Record 20 of set7 | dabhol
# Processing Record 21 of set7 | kahului
# Processing Record 22 of set7 | kurayoshi
# Processing Record 23 of set7 | berlevag
# Processing Record 24 of set7 | la ronge
# Processing Record 25 of set7 | vostok
# Processing Record 26 of set7 | ixtapa
# Processing Record 27 of set7 | miyang
# Processing Record 28 of set7 | gigmoto
# Processing Record 29 of set7 | pisco
# Processing Record 30 of set7 | grindavik
# Processing Record 31 of set7 | honiara
# Processing Record 32 of set7 | ontario
# Processing Record 33 of set7 | nong chik
# Processing Record 34 of set7 | northam
# Processing Record 35 of set7 | beloha
# City not found. Skipping ...
# Processing Record 36 of set7 | mezen
# City not found. Skipping ...
# Processing Record 37 of set7 | hampton
# Processing Record 38 of set7 | moosomin
# Processing Record 39 of set7 | longjiang
# City not found. Skipping ...
# Processing Record 40 of set7 | erzin
# Processing Record 41 of set7 | salaga
# Processing Record 42 of set7 | tivaouane
# Processing Record 43 of set7 | namatanai
# Processing Record 44 of set7 | gazojak
# Processing Record 45 of set7 | solnechnyy
# Processing Record 46 of set7 | prieska
# Processing Record 47 of set7 | nuuk
# Processing Record 48 of set7 | caravelas
# Processing Record 49 of set7 | port moresby
# Processing Record 50 of set7 | vanimo
# Processing Record 1 of set8 | charters towers
# Processing Record 2 of set8 | kamyshevatskaya
# Processing Record 3 of set8 | loreto
# Processing Record 4 of set8 | aksha
# Processing Record 5 of set8 | san pedro
# Processing Record 6 of set8 | kresttsy
# Processing Record 7 of set8 | pokhara
# Processing Record 8 of set8 | sao jose da coroa grande
# Processing Record 9 of set8 | hamilton
# Processing Record 10 of set8 | tucumcari
# Processing Record 11 of set8 | porangatu
# Processing Record 12 of set8 | kalabo
# Processing Record 13 of set8 | broome
# Processing Record 14 of set8 | soavinandriana
# Processing Record 15 of set8 | yarmouth
# City not found. Skipping ...
# Processing Record 16 of set8 | aldan
# Processing Record 17 of set8 | hudiksvall
# Processing Record 18 of set8 | oistins
# Processing Record 19 of set8 | balabac
# Processing Record 20 of set8 | andra
# Processing Record 21 of set8 | karasuk
# Processing Record 22 of set8 | mehamn
# Processing Record 23 of set8 | opuwo
# Processing Record 24 of set8 | iquique
# City not found. Skipping ...
# Processing Record 25 of set8 | salym
# Processing Record 26 of set8 | kananga
# Processing Record 27 of set8 | kroya
# Processing Record 28 of set8 | kenai
# Processing Record 29 of set8 | khor
# Processing Record 30 of set8 | la orilla
# Processing Record 31 of set8 | elko
# Processing Record 32 of set8 | gayny
# Processing Record 33 of set8 | delijan
# Processing Record 34 of set8 | hoi an
# Processing Record 35 of set8 | kalmunai
# Processing Record 36 of set8 | worthington
# Processing Record 37 of set8 | sheboygan
# Processing Record 38 of set8 | arkhangelsk
# City not found. Skipping ...
# Processing Record 39 of set8 | ballsh
# Processing Record 40 of set8 | whitehorse
# Processing Record 41 of set8 | almaznyy
# Processing Record 42 of set8 | sangar
# Processing Record 43 of set8 | baiao
# Processing Record 44 of set8 | okhotsk
# Processing Record 45 of set8 | ukiah
# Processing Record 46 of set8 | nakhon phanom
# Processing Record 47 of set8 | iberia
# Processing Record 48 of set8 | conde
# Processing Record 49 of set8 | oneonta
# City not found. Skipping ...
# Processing Record 50 of set8 | port-gentil
# Processing Record 1 of set9 | vega de alatorre
# Processing Record 2 of set9 | padang
# Processing Record 3 of set9 | gamba
# Processing Record 4 of set9 | plouzane
# Processing Record 5 of set9 | turukhansk
# Processing Record 6 of set9 | palana
# Processing Record 7 of set9 | miraflores
# Processing Record 8 of set9 | arlit
# City not found. Skipping ...
# Processing Record 9 of set9 | eyl
# Processing Record 10 of set9 | mahibadhoo
# Processing Record 11 of set9 | vestmanna
# Processing Record 12 of set9 | brandfort
# Processing Record 13 of set9 | bozuyuk
# Processing Record 14 of set9 | vila franca do campo
# Processing Record 15 of set9 | leshan
# Processing Record 16 of set9 | henties bay
# City not found. Skipping ...
# Processing Record 17 of set9 | saint-francois
# City not found. Skipping ...
# Processing Record 18 of set9 | ponta delgada
# Processing Record 19 of set9 | nemours
# Processing Record 20 of set9 | taiobeiras
# Processing Record 21 of set9 | ozernovskiy
# Processing Record 22 of set9 | gotsu
# Processing Record 23 of set9 | lokoja
# Processing Record 24 of set9 | coihaique
# Processing Record 25 of set9 | bad doberan
# Processing Record 26 of set9 | vilyuysk
# Processing Record 27 of set9 | ahuimanu
# Processing Record 28 of set9 | tazovskiy
# Processing Record 29 of set9 | xocali
# Processing Record 30 of set9 | vizinga
# Processing Record 31 of set9 | khandbari
# Processing Record 32 of set9 | laguna
# Processing Record 33 of set9 | faya
# Processing Record 34 of set9 | prado
# City not found. Skipping ...
# Processing Record 35 of set9 | mulege
# Processing Record 36 of set9 | batagay-alyta
# Processing Record 37 of set9 | marawi
# Processing Record 38 of set9 | newport
# Processing Record 39 of set9 | hovd
# Processing Record 40 of set9 | tahe
# Processing Record 41 of set9 | riohacha
# Processing Record 42 of set9 | abu samrah
# Processing Record 43 of set9 | barcelos
# Processing Record 44 of set9 | mazagao
# Processing Record 45 of set9 | ust-nera
# Processing Record 46 of set9 | jiwani
# Processing Record 47 of set9 | hofn
# Processing Record 48 of set9 | kloulklubed
# Processing Record 49 of set9 | paamiut
# Processing Record 50 of set9 | liverpool
# Processing Record 1 of set10 | barillas
# Processing Record 2 of set10 | nexo
# Processing Record 3 of set10 | hasanabad
# Processing Record 4 of set10 | meylan
# Processing Record 5 of set10 | trairi
# Processing Record 6 of set10 | parvatsar
# Processing Record 7 of set10 | falmouth
# Processing Record 8 of set10 | salinopolis
# Processing Record 9 of set10 | dunedin
# City not found. Skipping ...
# Processing Record 10 of set10 | port macquarie
# Processing Record 11 of set10 | avera
# Processing Record 12 of set10 | fort beaufort
# Processing Record 13 of set10 | baykit
# Processing Record 14 of set10 | zaranj
# Processing Record 15 of set10 | pierre
# Processing Record 16 of set10 | sungaipenuh
# Processing Record 17 of set10 | ginir
# City not found. Skipping ...
# Processing Record 18 of set10 | collie
# Processing Record 19 of set10 | sorong
# Processing Record 20 of set10 | birin
# Processing Record 21 of set10 | pauini
# Processing Record 22 of set10 | paciran
# Processing Record 23 of set10 | yeppoon
# Processing Record 24 of set10 | pekin
# Processing Record 25 of set10 | jiblah
# Processing Record 26 of set10 | taoudenni
# Processing Record 27 of set10 | natal
# Processing Record 28 of set10 | san miguel
# Processing Record 29 of set10 | raymond
# Processing Record 30 of set10 | launceston
# Processing Record 31 of set10 | huilong
# Processing Record 32 of set10 | along
# Processing Record 33 of set10 | novobirilyussy
# Processing Record 34 of set10 | chapais
# Processing Record 35 of set10 | mujiayingzi
# City not found. Skipping ...
# Processing Record 36 of set10 | vanavara
# Processing Record 37 of set10 | vao
# Processing Record 38 of set10 | mbalmayo
# Processing Record 39 of set10 | alugan
# Processing Record 40 of set10 | guerrero
# Processing Record 41 of set10 | taunggyi
# Processing Record 42 of set10 | nanortalik
# Processing Record 43 of set10 | zhireken
# Processing Record 44 of set10 | badou
# Processing Record 45 of set10 | tabou
# Processing Record 46 of set10 | yenagoa
# Processing Record 47 of set10 | skibbereen
# Processing Record 48 of set10 | nevelsk
# Processing Record 49 of set10 | bozhou
# Processing Record 50 of set10 | portland
# Processing Record 1 of set11 | soe
# City not found. Skipping ...
# Processing Record 2 of set11 | ormara
# Processing Record 3 of set11 | moerai
# Processing Record 4 of set11 | natchez
# Processing Record 5 of set11 | alice springs
# Processing Record 6 of set11 | indramayu
# Processing Record 7 of set11 | stephenville
# Processing Record 8 of set11 | henderson
# Processing Record 9 of set11 | najran
# Processing Record 10 of set11 | aykhal
# Processing Record 11 of set11 | pirna
# Processing Record 12 of set11 | marsh harbour
# Processing Record 13 of set11 | belmonte
# City not found. Skipping ...
# Processing Record 14 of set11 | puerto el triunfo
# --------------------------------------------------
# Data Retrieval Complete
# --------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe with required items
city_data_df = pd.DataFrame({'City': city_name,
                             'Country': country,
                             'Lat': lat,
                             'Long': long,
                             'Date': date,
                             'Max Temp': maxTemp,
                             'Humidity': humidity,
                             'Cloudiness': clouds,
                             'Wind Speed': wind})

# export the city data into a .csv
pd.DataFrame.to_csv(city_data_df, 'city_data.csv')

# %%
city_data_df.count()
# Out:
# City          514
# Country       514
# Lat           514
# Long          514
# Date          514
# Max Temp      514
# Humidity      514
# Cloudiness    514
# Wind Speed    514
# dtype: int64

# %%
city_data_df.head()
# Out:
#            City Country    Lat    Long        Date  Max Temp  Humidity  \
# 0  Ponta do Sol      BR -20.63  -46.00  1573950749     68.95        80
# 1       Rikitea      PF -23.12 -134.97  1573950749     74.84        83
# 2     Mahebourg      MU -20.41   57.70  1573950749     75.99        83
# 3        Atuona      PF  -9.80 -139.03  1573950750     80.11        70
# 4   Devils Lake      US  48.11  -98.87  1573950750     37.40        74
#
#    Cloudiness  Wind Speed
# 0          31        4.34
# 1          71       14.61
# 2          40       12.75
# 3           2       13.56
# 4          90       20.80

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plotting the data from the city data frame
plt.scatter(x = city_data_df["Lat"], y = city_data_df["Max Temp"], marker="o",
             facecolors = 'blue', edgecolors = 'black', linewidths = 0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (11/15/19)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Temperature.png")

# Show plot
plt.show()

# %%
# d = date.today()
# print (d)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plotting the data from the city data frame
plt.scatter(x = city_data_df["Lat"], y = city_data_df["Humidity"], marker="o",
            facecolors = 'blue', edgecolors = 'black', linewidths = 0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (11/15/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plotting the data from the city data frame
plt.scatter(x = city_data_df["Lat"], y = city_data_df["Cloudiness"], marker="o",
            facecolor = 'blue', edgecolors = 'black', linewidths = 0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (11/15/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plotting the data from the city data frame
plt.scatter(x = city_data_df["Lat"], y = city_data_df["Wind Speed"], marker="o",
            facecolor = 'blue', edgecolors = 'black', linewidths = 0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (11/15/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_WindSpeed.png")

# Show plot
plt.show()
